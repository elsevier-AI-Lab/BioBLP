# %%
import pyobo
import pandas as pd

import json
import hetnetpy
from pathlib import Path

# %%
hetio_data_path = Path('/Users/dalivas/Documents/Projects/hetionet/hetnet')

# %%
hetio_json_path = hetio_data_path.joinpath('/json/')

# %%
from hetnetpy.readwrite import open_read_file, load

# %%
read_file = open_read_file('../data/hetionet/hetionet-v1.0.json')

hetio_data = load(read_file, formatting='json')

# %%
gene_dict = {}

for node in hetio_data['nodes']:
    if node['kind'] == 'Gene':
        gene_dict[node['identifier']] = node['data']['url']

# %%
len(gene_dict)
# Out:
# 20945

# %%
hgnc_mapping = pd.read_csv('../data/hetionet/hgnc_id_mapping.txt', sep='\t')

# %%
hgnc_mapping
# Out:
#           HGNC ID RefSeq IDs  NCBI Gene ID UniProt ID(supplied by UniProt)
# 0          HGNC:1        NaN           NaN                             NaN
# 1         HGNC:10        NaN           NaN                             NaN
# 2        HGNC:100  NM_020039          41.0                          P78348
# 3       HGNC:1000        NaN           NaN                             NaN
# 4      HGNC:10000  NM_005613        5999.0                          P49798
# ...           ...        ...           ...                             ...
# 48658   HGNC:9995  NM_002927        6003.0                          O14921
# 48659   HGNC:9996  NM_006480       10636.0                          O43566
# 48660   HGNC:9997  NM_002928        6004.0                          O15492
# 48661   HGNC:9998  NM_002923        5997.0                          P41220
# 48662   HGNC:9999  NM_017790        5998.0                          P49796
#
# [48663 rows x 4 columns]

# %%
hgnc_mapping[hgnc_mapping['UniProt ID(supplied by UniProt)']]
# Out:
#         HGNC ID RefSeq IDs  NCBI Gene ID UniProt ID(supplied by UniProt)
# 619  HGNC:10561  NR_002717        6315.0                          P0DMR3

# %%
hgnc_ncbi_uniprot = hgnc_mapping[['NCBI Gene ID', 'UniProt ID(supplied by UniProt)']]

# %%
hgnc_ncbi_uniprot = hgnc_ncbi_uniprot.dropna(axis=0,)

# %%
hgnc_ncbi_uniprot['NCBI Gene ID'] = hgnc_ncbi_uniprot['NCBI Gene ID'].astype(int)

# %%
hgnc_ncbi_uniprot
# Out:
#        NCBI Gene ID UniProt ID(supplied by UniProt)
# 2                41                          P78348
# 4              5999                          P49798
# 5              8490                          O15539
# 6              9628                          P49758
# 7              6000                          P49802
# ...             ...                             ...
# 48658          6003                          O14921
# 48659         10636                          O43566
# 48660          6004                          O15492
# 48661          5997                          P41220
# 48662          5998                          P49796
#
# [20104 rows x 2 columns]

# %%
hgnc_ncbi_uniprot
# Out:
#        NCBI Gene ID UniProt ID(supplied by UniProt)
# 2                41                          P78348
# 4              5999                          P49798
# 5              8490                          O15539
# 6              9628                          P49758
# 7              6000                          P49802
# ...             ...                             ...
# 48658          6003                          O14921
# 48659         10636                          O43566
# 48660          6004                          O15492
# 48661          5997                          P41220
# 48662          5998                          P49796
#
# [20104 rows x 2 columns]

# %%
hgnc_ncbi_uniprot['NCBI Gene ID'] = hgnc_ncbi_uniprot['NCBI Gene ID'].apply(lambda x: gene_dict[x] 
                                                                            if x in gene_dict.keys() else None)

# %%
nan_rows = hgnc_ncbi_uniprot[hgnc_ncbi_uniprot['NCBI Gene ID'].isnull()]

# %%
nan_rows
# Out:
#       NCBI Gene ID UniProt ID(supplied by UniProt)
# 80            None                          P0C6P0
# 619           None                          P0DMR3
# 625           None                          Q9GZW5
# 784           None                          P0DI82
# 1882          None                          P51864
# ...            ...                             ...
# 47919         None                          Q9NRI7
# 48048         None                          O43930
# 48195         None                          O15172
# 48385         None                          Q9NRI6
# 48643         None                          P0C7P2
#
# [1041 rows x 2 columns]

# %%
hgnc_ncbi_uniprot
# Out:
#                                 NCBI Gene ID UniProt ID(supplied by UniProt)
# 2         http://identifiers.org/ncbigene/41                          P78348
# 4       http://identifiers.org/ncbigene/5999                          P49798
# 5       http://identifiers.org/ncbigene/8490                          O15539
# 6       http://identifiers.org/ncbigene/9628                          P49758
# 7       http://identifiers.org/ncbigene/6000                          P49802
# ...                                      ...                             ...
# 48658   http://identifiers.org/ncbigene/6003                          O14921
# 48659  http://identifiers.org/ncbigene/10636                          O43566
# 48660   http://identifiers.org/ncbigene/6004                          O15492
# 48661   http://identifiers.org/ncbigene/5997                          P41220
# 48662   http://identifiers.org/ncbigene/5998                          P49796
#
# [20104 rows x 2 columns]

# %%
import torch

# %%
protein_emb = torch.load('../data/processed/protein_embeddings_full.pt')

# %%
test = torch.load('../data/processed/prot_id_to_embedding.pt')

# %%
identifier_list = test.index.to_list()

# %%
id_set_0 = set(identifier_list)

# %%
id_set_1 = set(hgnc_ncbi_uniprot['UniProt ID(supplied by UniProt)'])

# %%
id_set_1
# Out:
# {'Q16526',
#  'P60608',
#  'Q9NRY4',
#  'Q9Y5I2',
#  'O43869',
#  'O75871',
#  'Q5SZB4',
#  'O60645',
#  'Q9C0F3',
#  'Q9H5K3',
#  'Q8WW35',
#  'Q9H9V4',
#  'P11498',
#  'Q7Z3Z2',
#  'Q92692',
#  'Q16595',
#  'Q14145',
#  'P16442',
#  'Q9H425',
#  'P0CG42',
#  'Q8WXH0',
#  'Q9H7V2',
#  'Q5JSL3',
#  'O94880',
#  'O15392',
#  'Q9UH64',
#  'Q9NR23',
#  'P56962',
#  'Q9Y6V0',
#  'Q9H8X9',
#  'Q96DU9',
#  'Q8N1B4',
#  'Q96F86',
#  'Q96DC9',
#  'Q9H4Z3',
#  'Q9UHL4',
#  'Q9BW91',
#  'P07478',
#  'O95210',
#  'Q8N6Q3',
#  'Q9P2D0',
#  'Q01094',
#  'Q6ZNJ1',
#  'Q9UF56',
#  'O14958',
#  'Q5SWW7',
#  'Q5KSL6',
#  'O15145',
#  'O00634',
#  'Q09470',
#  'O95183',
#  'Q96TA1',
#  'Q7Z388',
#  'Q9BXU0',
#  'Q9H4E7',
#  'Q92667',
#  'O95336',
#  'Q14159',
#  'Q9UPR0',
#  'P61583, Q9HDB8, Q9HDB9',
#  'Q5T6S3',
#  'Q9Y5H9',
#  'Q6ZVD8',
#  'Q969G9',
#  'Q9P2E2',
#  'Q8NCN2',
#  'Q8NGI3',
#  'Q96L50',
#  'Q86UV6',
#  'Q7Z7H8',
#  'Q6T310',
#  'Q99973',
#  'Q5TZ20',
#  'Q96R08',
#  'Q9H6I2',
#  'Q8NFB2',
#  'A0A0A0MT76',
#  'Q08462',
#  'P08651',
#  'Q9H3R2',
#  'Q9GZN8',
#  'Q494U1',
#  'Q5VZQ5',
#  'Q9UKV3',
#  'O94933',
#  'Q7Z434',
#  'Q8N8E1',
#  'Q9HCS5',
#  'Q9H6A0',
#  'Q9Y3T6',
#  'Q6UXD5',
#  'Q9NYJ7',
#  'Q07699',
#  'Q9ULD6',
#  'P02724',
#  'P13164',
#  'P27986',
#  'Q96LB0',
#  'Q8IZ08',
#  'Q8WXK4',
#  'Q8N1G1',
#  'Q9NRG9',
#  'Q8IX03',
#  'P18509',
#  'Q9NU02',
#  'A6NET4',
#  'Q96T37',
#  'Q9NY59',
#  'Q92556',
#  'Q9UK05',
#  'Q9UBV4',
#  'P05089',
#  'Q9BX74',
#  'Q14093',
#  'P25787',
#  'Q8WWQ0',
#  'Q6MZM9',
#  'Q9UPX8',
#  'Q9UKY0',
#  'Q86Y46',
#  'P31321',
#  'Q6ZRH7',
#  'C9JLR9',
#  'P15309',
#  'O75912',
#  'Q96C55',
#  'Q05D60',
#  'Q14129',
#  'P83916',
#  'P15336',
#  'Q9H361',
#  'Q9NXT0',
#  'Q9NYQ8',
#  'P47914',
#  'Q9BVJ6',
#  'Q9NRG4',
#  'Q7Z7C7',
#  'Q9BWC9',
#  'Q8TCT7',
#  'P11137',
#  'Q99983',
#  'Q495A1',
#  'P54136',
#  'Q13326',
#  'P01574',
#  'Q9UKQ9',
#  'Q9HAV5',
#  'Q5TCY1',
#  'Q9BXI9',
#  'A6NIM6',
#  'P49760',
#  'Q8N687',
#  'Q9NY99',
#  'Q9NYS0',
#  'P34931',
#  'Q5H9I0',
#  'Q10981',
#  'Q7Z402',
#  'Q9C0H5',
#  'P01714',
#  'Q9UJV8',
#  'A0A0B4J237',
#  'Q8NCF0',
#  'Q9HAZ2',
#  'Q9Y2X7',
#  'A1L157',
#  'Q13268',
#  'Q9BTV5',
#  'Q8NI77',
#  'Q12805',
#  'P51959',
#  'Q8N8F7',
#  'Q92523',
#  'Q9Y3Z3',
#  'Q96P67',
#  'P0DM63',
#  'A8MXQ7',
#  'Q5VXU3',
#  'P16410',
#  'Q9NPG8',
#  'Q6IPR3',
#  'Q9H9P2',
#  'A8MTI9',
#  'Q92974',
#  'Q8IWU2',
#  'O43909',
#  'O15021',
#  'Q6P2S7',
#  'P46098',
#  'Q6P1M0',
#  'P17039',
#  'Q8TAL6',
#  'Q92934',
#  'Q99988',
#  'Q8IUX4',
#  'O15397',
#  'Q8N9N7',
#  'Q8N159',
#  'Q8NG84',
#  'Q8NCG5',
#  'P85299',
#  'Q8N5F7',
#  'Q6WRI0',
#  'Q8WTS1',
#  'P52565',
#  'Q9UKX2',
#  'O75677',
#  'Q9UKY1',
#  'P0DOY3',
#  'Q14146',
#  'Q96JD6',
#  'E5RIL1',
#  'Q6NXT4',
#  'Q7L804',
#  'P08729',
#  'Q14728',
#  'Q96L91',
#  'P01764',
#  'Q9Y673',
#  'Q8N9Z0',
#  'Q8IXF9',
#  'O95971',
#  'Q8WV37',
#  'Q9GZW5',
#  'Q96M02',
#  'Q9NSI2',
#  'P45844',
#  'Q7Z4K8',
#  'Q8IXS0',
#  'Q96AE7',
#  'Q2TBE0',
#  'Q13772',
#  'P0CG36',
#  'Q9H4M9',
#  'Q9Y315',
#  'Q86WS4',
#  'Q8NGK3',
#  'Q9BYQ9',
#  'Q9NP59',
#  'P11161',
#  'Q9NVH1',
#  'Q96F05',
#  'P67809',
#  'P58180',
#  'Q16627',
#  'Q9UIL8',
#  'Q9Y2I7',
#  'F8WFD2',
#  'Q12968',
#  'P0C7V7',
#  'P02655',
#  'Q96FS4',
#  'Q9NXL2',
#  'Q9BZ71',
#  'Q02080',
#  'P61366',
#  'Q9UPS6',
#  'P46781',
#  'Q17RB8',
#  'Q8TF46',
#  'P24863',
#  'Q658N2',
#  'Q9NR55',
#  'Q8N6G2',
#  'Q6UX04',
#  'Q96P71',
#  'Q9UNI6',
#  'Q15024',
#  'Q8IX90',
#  'Q5TIE3',
#  'Q8NFM7',
#  'Q06787',
#  'Q92545',
#  'Q9UHL0',
#  'Q16609',
#  'Q8WWW0',
#  'Q8NBQ7',
#  'Q9NQ34',
#  'O43405',
#  'P50570',
#  'P0CI25',
#  'P26951',
#  'O14604',
#  'Q99873',
#  'O95067',
#  'O15116',
#  'A7MD48',
#  'Q16559',
#  'Q9UI95',
#  'Q01844',
#  'Q12834',
#  'Q9UM13',
#  'Q6UXZ4',
#  'A0A0K0K1C0',
#  'Q9P278',
#  'Q92563',
#  'Q6ZP65',
#  'Q9H6Y7',
#  'Q8NA58',
#  'A0A1B0GVY4',
#  'Q5T2D2',
#  'A2A288',
#  'O94923',
#  'Q9BXW6',
#  'P30154',
#  'O14841',
#  'Q6ZRP7',
#  'Q8TDR0',
#  'P30085',
#  'Q8TDW7',
#  'P57740',
#  'P51686',
#  'O60447',
#  'A5PLL1',
#  'Q504Y3',
#  'P0CJ68',
#  'Q9NZB8',
#  'Q6P1R3',
#  'Q96S16',
#  'O75128',
#  'Q99969',
#  'Q9HCJ1',
#  'Q86YL7',
#  'Q8NG97',
#  'Q13938',
#  'Q1MX18',
#  'Q8N0V1',
#  'Q9NYN1',
#  'Q9Y3D8',
#  'Q5TFG8',
#  'Q8IWD5',
#  'P58418',
#  'Q9HCD6',
#  'P61575, P62685, P63122, P63133, Q902F8',
#  'A0A0B4J272',
#  'Q96AD5',
#  'Q5D0E6',
#  'Q08174',
#  'Q6P1X6',
#  'Q01449',
#  'Q86YJ5',
#  'Q9H5Y7',
#  'Q92997',
#  'Q8TD07',
#  'P23471',
#  'Q9BS34',
#  'Q9GZT8',
#  'Q5NDL2',
#  'A0A0J9YXG5',
#  'Q96EP9',
#  'P06315',
#  'Q9Y2T4',
#  'P07315',
#  'Q9BWF2',
#  'Q9BT78',
#  'Q68CP9',
#  'P62701',
#  'P0DP09',
#  'Q8IW70',
#  'Q9BWK5',
#  'Q9HCB6',
#  'Q15011',
#  'Q04900',
#  'Q15047',
#  'Q8NEY8',
#  'P60660',
#  'P17676',
#  'P36405',
#  'A8MXU0',
#  'Q6PKX4',
#  'Q8N8I0',
#  'Q8NHW3',
#  'O43586',
#  'O14730',
#  'Q9Y5H5',
#  'Q9HCJ0',
#  'P31153',
#  'Q9H426',
#  'Q6VEQ5',
#  'Q9NVG8',
#  'Q6PF06',
#  'Q9Y2D4',
#  'P59551',
#  'Q8IW03',
#  'Q9HBF4',
#  'Q5W5X9',
#  'Q14206',
#  'Q13421',
#  'Q9UBP6',
#  'Q7Z353',
#  'Q9UKV5',
#  'O43525',
#  'Q8IUE0',
#  'P0CG29',
#  'Q8NAA5',
#  'Q8WZA2',
#  'Q68DE3',
#  'P0DP04',
#  'Q9NRR6',
#  'P53816',
#  'Q9NXZ1',
#  'Q5BKT4',
#  'O14522',
#  'Q9BWF3',
#  'Q9BQ15',
#  'Q9BY66',
#  'Q8IZF4',
#  'Q96JM3',
#  'Q9UKZ4',
#  'Q9UKJ8',
#  'Q14789',
#  'Q08493',
#  'A0A075B6N2',
#  'Q9UNQ2',
#  'Q96S95',
#  'Q96QH2',
#  'Q17RC7',
#  'P26718',
#  'O75503',
#  'Q8NBS9',
#  'Q9UKG9',
#  'O14735',
#  'Q8NFY9',
#  'O95214',
#  'Q96RQ9',
#  'Q9Y383',
#  'O75907',
#  'Q92782',
#  'Q9BTD1',
#  'A4QPH2',
#  'Q8NB16',
#  'Q9BXC0',
#  'P15622',
#  'Q6ZT07',
#  'Q9H213',
#  'P01036',
#  'A6NCN8',
#  'P56181',
#  'A0A0A0MS02',
#  'O15371',
#  'Q9BZ81',
#  'A0A1B0GVZ9',
#  'Q9HCK4',
#  'Q9H611',
#  'Q8N4W6',
#  'Q96LT9',
#  'O43314',
#  'Q9NYQ3',
#  'Q96CC6',
#  'Q5TGU0',
#  'Q86U90',
#  'O14939',
#  'Q9NZW5',
#  'Q9UIY3',
#  'P17936',
#  'Q13188',
#  'Q8NC56',
#  'P0DJD3',
#  'Q8IV35',
#  'Q9Y2G9',
#  'Q6IQ32',
#  'Q9UL51',
#  'P15976',
#  'O14964',
#  'Q53R41',
#  'O00488',
#  'P53597',
#  'Q7Z602',
#  'P48551',
#  'Q8NC51',
#  'O75390',
#  'Q9C0J1',
#  'Q8WTV1',
#  'A6NGH8',
#  'Q9Y2C4',
#  'Q96A70',
#  'Q9Y5G4',
#  'O43520',
#  'Q9Y5N5',
#  'Q9H158',
#  'Q9H892',
#  'O43566',
#  'Q6UXC1',
#  'P06127',
#  'Q8NCF5',
#  'Q96T76',
#  'Q86XI2',
#  'P07766',
#  'Q7Z333',
#  'P31260',
#  'O75344',
#  'Q9Y320',
#  'Q9UP95',
#  'Q9UHC1',
#  'Q9Y258',
#  'Q8TCB0',
#  'O43617',
#  'Q9NYV4',
#  'Q9BQI9',
#  'Q96BN6',
#  'Q0VDD8',
#  'Q8IV16',
#  'P0CG48',
#  'P0CI26',
#  'Q9P296',
#  'P00973',
#  'Q9BZF3',
#  'O75838',
#  'Q3SYA9',
#  'Q969T4',
#  'Q5BKY1',
#  'P42830',
#  'Q9H7J1',
#  'Q16348',
#  'Q13886',
#  'P41161',
#  'Q8NHV9',
#  'Q8IV56',
#  'O95988',
#  'Q9UK22',
#  'Q5SZK8',
#  'P48594',
#  'Q9UHJ6',
#  'Q9P0M4',
#  'P62987',
#  'Q16656',
#  'Q8IUH4',
#  'Q68D06',
#  'Q02556',
#  'Q9Y324',
#  'Q9BT92',
#  'Q15077',
#  'Q8WV60',
#  'Q92835',
#  'Q86WW8',
#  'Q9NS82',
#  'Q9HBI1',
#  'P10415',
#  'Q14774',
#  'Q6P1K8',
#  'Q71RG4',
#  'Q16280',
#  'Q9H9L3',
#  'P54098',
#  'Q16385',
#  'A0A075B6V5',
#  'Q6P2H3',
#  'Q6ZTR6',
#  'Q96PS1',
#  'Q8IVD9',
#  'Q96EF6',
#  'Q96A29',
#  'Q6P597',
#  'Q5W0B1',
#  'A6NER0',
#  'Q96MH2',
#  'Q9HC29',
#  'Q99250',
#  'Q8N4Z0',
#  'Q86YF9',
#  'Q9UII4',
#  'P01562',
#  'Q0P5P2',
#  'Q9BUZ4',
#  'Q9NS40',
#  'O95461',
#  'P08514',
#  'Q9H4L7',
#  'Q9BZP6',
#  'Q9NUJ3',
#  'A6NDH6',
#  'P13807',
#  'Q9BYE0',
#  'Q5H943',
#  'P39880, Q13948',
#  'Q0GE19',
#  'P01889',
#  'O43715',
#  'Q9Y2B4',
#  'Q96S66',
#  'Q8IY37',
#  'Q86YS6',
#  'A0A494C086',
#  'Q53EV4',
#  'P00915',
#  'Q52LJ0',
#  'Q7Z5R6',
#  'O94925',
#  'Q3B8N2',
#  'Q5VZ03',
#  'Q9UQQ2',
#  'Q5VT52',
#  'Q9ULL4',
#  'Q01101',
#  'O43422',
#  'Q9Y2B1',
#  'Q5JTJ3',
#  'Q8NBQ5',
#  'Q9BQK8',
#  'Q99547',
#  'Q8NGX8',
#  'Q9NZC7',
#  'Q8TCB7',
#  'Q9HCJ5',
#  'O75448',
#  'P49959',
#  'P21506',
#  'Q9H1M0',
#  'Q9BWV1',
#  'Q0P670',
#  'Q6UX52',
#  'A0A5B9',
#  'P09430',
#  'Q9NWY4',
#  'P62269',
#  'Q9BRH9',
#  'P16401',
#  'Q9UKT5',
#  'Q8NH16',
#  'P0DPD6',
#  'Q8N5C6',
#  'Q86V88',
#  'P01772',
#  'P0CK97',
#  'Q9HD40',
#  'O14757',
#  'O75762',
#  'Q8NGK4',
#  'O95486',
#  'Q8NHP6',
#  'Q9NSI5',
#  'H0UI37',
#  'Q99941',
#  'P0DMQ5',
#  'Q13283',
#  'Q5SWL7',
#  'Q7Z6K3',
#  'P01589',
#  'P16070',
#  'P36268',
#  'Q86YW7',
#  'Q3KNT9',
#  'Q9Y5P0',
#  'P43304',
#  'P49366',
#  'Q15560',
#  'Q9BQ90',
#  'O75821',
#  'P78352',
#  'Q2KHT4',
#  'Q13085',
#  'Q2TB18',
#  'Q8NB91',
#  'A0A1W2PPL8',
#  'Q8N6S4',
#  'Q8N819',
#  'Q5SWL8',
#  'O15504',
#  'Q6AZY7',
#  'O15105',
#  'Q96LA5',
#  'P50225',
#  'Q9P2N5',
#  'P42261',
#  'O43511',
#  'Q01995',
#  'Q5SR53',
#  'Q8WVS4',
#  'P29322',
#  'Q9UNE2',
#  'P20338',
#  'Q9NY46',
#  'Q16394',
#  'Q9UPW5',
#  'Q6XR72',
#  'Q3B7J2',
#  'Q5RL73',
#  'Q9H346',
#  'Q8N8G2',
#  'Q9UNH6',
#  'Q9NY12',
#  'P47897',
#  'Q9Y6I4',
#  'Q8N1E6',
#  'Q14126',
#  'Q15393',
#  'P32926',
#  'Q9Y6E0',
#  'P54802',
#  'Q8IY42',
#  'Q7Z5Q5',
#  'O75920',
#  'Q9HBE4',
#  'Q9NPA1',
#  'Q2Q1W2',
#  'O95185',
#  'Q9C004',
#  'P05060',
#  'Q99440',
#  'Q9BV38',
#  'Q02246',
#  'O14559',
#  'P10412',
#  'Q9H4P4',
#  'Q8NAG6',
#  'Q9UPT8',
#  'P01601',
#  'O75717',
#  'Q8ND61',
#  'Q7Z494',
#  'A6NED2',
#  'Q9UPZ9',
#  'Q9HB90',
#  'Q9UBV8',
#  'Q7Z5K2',
#  'Q9BXF3',
#  'Q86XA0',
#  'P0CJ87',
#  'Q4VCS5',
#  'Q9Y4P1',
#  'Q00005',
#  'Q96PP9',
#  'Q8TEJ3',
#  'O60241',
#  'P53004',
#  'Q86V48',
#  'P15529',
#  'O95865',
#  'Q9H7T0',
#  'Q6ZRV3',
#  'Q9BWW4',
#  'P48147',
#  'Q8IXQ9',
#  'Q92611',
#  'P14618',
#  'Q9H1F0',
#  'Q96N66',
#  'Q9BYV2',
#  'P55290',
#  'O14832',
#  'Q14DG7',
#  'P63165',
#  'P46940',
#  'A2RUS2',
#  'O94876',
#  'O00214',
#  'Q9H7P6',
#  'Q9P2H5',
#  'Q96A83',
#  'Q53EL9',
#  'Q6VUC0',
#  'Q92752',
#  'Q2TBC4',
#  'Q8NHZ7',
#  'Q14005',
#  'O60462',
#  'P00813',
#  'Q96JE7',
#  'P29558',
#  'Q9BRI3',
#  'Q5JRM2',
#  'O43653',
#  'Q96LY2',
#  'Q8N8A2',
#  'H3BQW9',
#  'P0DV75',
#  'Q06055',
#  'Q9HBG4',
#  'Q96SB8',
#  'Q8NAP1',
#  'O43559',
#  'Q495C1',
#  'Q8NHV1',
#  'O76083',
#  'P59103',
#  'A5X5Y0',
#  'Q9BV40',
#  'Q9NYL4',
#  'Q13255',
#  'Q86XT4',
#  'Q9NRC6',
#  'O95786',
#  'A0A0J9YX75',
#  'Q9GZU8',
#  'Q8NA03',
#  'Q9BQ87',
#  'P29376',
#  'Q96HD9',
#  'Q6PIJ6',
#  'Q92886',
#  'A0A087WXS9',
#  'Q96SF7',
#  'Q5TYW1',
#  'Q9NUQ7',
#  'Q9BZL4',
#  'Q9ULV4',
#  'Q969X0',
#  'Q8NB25',
#  'Q5VXJ0',
#  'P35556',
#  'Q8IV03',
#  'P48741',
#  'Q13835',
#  'Q03828',
#  'P01594',
#  'Q9UPR3',
#  'P49427',
#  'P0C851',
#  'Q5VW38',
#  'Q53RE8',
#  'Q6P587',
#  'O75674',
#  'Q99956',
#  'Q9H8N7',
#  'Q86UU9',
#  'Q9Y6F6',
#  'Q6L8G9',
#  'Q8WUY9',
#  'Q6ZVX7',
#  'Q9H0R5',
#  'Q03519',
#  'Q16611',
#  'O60299',
#  'Q96CG3',
#  'O00222',
#  'P60953',
#  'P02786',
#  'P01737',
#  'Q8N5C8',
#  'Q9Y6X0',
#  'Q9Y2Y0',
#  'Q9C056',
#  'P47887',
#  'A2AJT9',
#  'Q96AM1',
#  'Q96I15',
#  'Q06203',
#  'Q16825',
#  'A6NCF5',
#  'P0DN77',
#  'Q86YD1',
#  'Q9Y2E4',
#  'Q8WZ71',
#  'A8MTJ6',
#  'O60224',
#  'Q96CM3',
#  'Q5FYB0',
#  'Q5VSP4',
#  'Q7L5L3',
#  'Q8N967',
#  'P35998',
#  'Q6ZMJ2',
#  'P47211',
#  'Q9H8J5',
#  'O95070',
#  'O95843',
#  'P09603',
#  'Q8WYL5',
#  'Q9BYV7',
#  'P35227',
#  'Q8NAN2',
#  'Q8NBR6',
#  'A6NL82',
#  'Q9H4E5',
#  'P47224',
#  'P36955',
#  'Q9BXA7',
#  'H3BV12',
#  'Q9UN19',
#  'Q9H1E1',
#  'O75394',
#  'Q6NYC8',
#  'Q5T7P2',
#  'Q15438',
#  'O14975',
#  'A8K0Z3',
#  'Q9NVZ3',
#  'A6NMB9',
#  'A0A0A6YYK7',
#  'O60711',
#  'Q8NFH8',
#  'Q8IWL3',
#  'Q14974',
#  'Q8IUK8',
#  'Q96P44',
#  'Q969W3',
#  'O00221',
#  'P20073',
#  'Q8NGG3',
#  'P22309',
#  'Q12931',
#  'Q86WX3',
#  'Q6NUT2',
#  'O95452',
#  'A6NCL1',
#  'Q9P242',
#  'Q3SXZ7',
#  'Q86SU0',
#  'O95925',
#  'Q96Q07',
#  'Q8N6U2',
#  'Q9BYC2',
#  'Q2VYF4',
#  'Q9UJ70',
#  'Q8TES7',
#  'P10909',
#  'A0A087WSY4',
#  'Q9UK17',
#  'Q96KX2',
#  'P22307',
#  'A8MWY0',
#  'Q9H898',
#  'O60330',
#  'Q13618',
#  'A6NIR3',
#  'Q9H172',
#  'Q9H4I9',
#  'Q2M3V2',
#  'Q9BSG5',
#  'Q16572',
#  'Q9UMX1',
#  'P14210',
#  'Q8IWR0',
#  'Q5JXA9',
#  'Q8NG41',
#  'Q8N4C7',
#  'Q9H4F1',
#  'Q9UJ99',
#  'Q8IWV1',
#  'P82094',
#  'Q9NUD7',
#  'Q9BYT1',
#  'Q9NQF3',
#  'O94811',
#  'Q5JR98',
#  'Q9NVE7',
#  'Q9UJM8',
#  'Q9BXI6',
#  'O60296',
#  'Q5EBM0',
#  'Q5VST9',
#  'P05386',
#  'O15144',
#  'Q9BU19',
#  'A4D126',
#  'Q9Y4C5',
#  'Q14738',
#  'Q16473',
#  'Q6Q4G3',
#  'Q5W0B7',
#  'P47898',
#  'Q86SQ0',
#  'Q9HB29',
#  'Q5VUD6',
#  'Q86UC2',
#  'O14617',
#  'Q5VWP3',
#  'Q14525',
#  'Q6UWI2',
#  'P62750',
#  'Q96D21',
#  'Q8TE76',
#  'Q96NW4',
#  'P78524',
#  'P36508',
#  'P31939',
#  'Q32M78',
#  'Q6DN03',
#  'P35749',
#  'Q96KN1',
#  'Q8NBT0',
#  'Q8NFF2',
#  'Q8TF45',
#  'P86496',
#  'Q9NRJ2',
#  'A4QN01',
#  'Q5VWG9',
#  'Q9UFV1',
#  'P53804',
#  'A6NLX4',
#  'P59991',
#  'Q96M91',
#  'O60331',
#  'Q9NQX1',
#  'A0A5A6',
#  'Q16718',
#  'Q9UBM4',
#  'Q5T7W7',
#  'Q05066',
#  'Q5VWM6',
#  'P53701',
#  'O00139',
#  'Q96R45',
#  'Q15389',
#  'Q8NHP1',
#  'P19474',
#  'Q6H8Q1',
#  'Q96N20',
#  'Q9Y2K5',
#  'O15234',
#  ...}

# %%
hgnc_ncbi_uniprot[[', ' in x for x in hgnc_ncbi_uniprot['UniProt ID(supplied by UniProt)']]]
# Out:
#                                     NCBI Gene ID  \
# 932         http://identifiers.org/ncbigene/7979
# 1744         http://identifiers.org/ncbigene/706
# 2071        http://identifiers.org/ncbigene/7112
# 2205       http://identifiers.org/ncbigene/27433
# 2241        http://identifiers.org/ncbigene/6955
# 2383        http://identifiers.org/ncbigene/6957
# 3932       http://identifiers.org/ncbigene/23499
# 4011                                        None
# 4139                                        None
# 4589         http://identifiers.org/ncbigene/796
# 5081       http://identifiers.org/ncbigene/81488
# 6155       http://identifiers.org/ncbigene/10326
# 6771       http://identifiers.org/ncbigene/83871
# 7995       http://identifiers.org/ncbigene/27113
# 7997        http://identifiers.org/ncbigene/1029
# 8331       http://identifiers.org/ncbigene/22891
# 9690       http://identifiers.org/ncbigene/51207
# 10446      http://identifiers.org/ncbigene/51082
# 10718     http://identifiers.org/ncbigene/113829
# 11908                                       None
# 12003     http://identifiers.org/ncbigene/284293
# 12993     http://identifiers.org/ncbigene/163590
# 13269      http://identifiers.org/ncbigene/64693
# 13544       http://identifiers.org/ncbigene/9910
# 14007     http://identifiers.org/ncbigene/115509
# 14383       http://identifiers.org/ncbigene/1523
# 14496       http://identifiers.org/ncbigene/8933
# 14764      http://identifiers.org/ncbigene/54471
# 15898       http://identifiers.org/ncbigene/1649
# 18561      http://identifiers.org/ncbigene/23513
# 19218     http://identifiers.org/ncbigene/399687
# 19860                                       None
# 20333                                       None
# 22123       http://identifiers.org/ncbigene/7957
# 22368       http://identifiers.org/ncbigene/2074
# 25870       http://identifiers.org/ncbigene/9465
# 26881  http://identifiers.org/ncbigene/100526773
# 27057                                       None
# 31507       http://identifiers.org/ncbigene/2778
# 45557       http://identifiers.org/ncbigene/4338
# 46033       http://identifiers.org/ncbigene/4666
# 46455       http://identifiers.org/ncbigene/9378
# 46456       http://identifiers.org/ncbigene/9379
# 46458       http://identifiers.org/ncbigene/9369
# 48003       http://identifiers.org/ncbigene/5583
# 48053       http://identifiers.org/ncbigene/5621
# 48548       http://identifiers.org/ncbigene/8241
#
#               UniProt ID(supplied by UniProt)
# 932                            P60896, Q6ZVN7
# 1744                           B1AH88, P30536
# 2071                           P42166, P42167
# 2205                           Q5JU69, Q8N2E6
# 2241                           P0DSE1, P0DTU3
# 2383                           P0DSE2, P0DTU4
# 3932                           O94854, Q9UPN3
# 4011                   P61583, Q9HDB8, Q9HDB9
# 4139   Q69383, Q69384, Q7LDI9, Q9BXR3, Q9Y6I0
# 4589                           P01258, P06881
# 5081                           P0CAP2, Q6EEV4
# 6155                           O00241, Q5TFQ8
# 6771                           P0DI83, Q9BZG1
# 7995                           Q96PG8, Q9BXH1
# 7997                           P42771, Q8N726
# 8331                           Q70YC4, Q70YC5
# 9690                           Q6B8I1, Q9UII6
# 10446                          P0DPB5, P0DPB6
# 10718                          L0R6Q1, Q96G79
# 11908                          Q6XLA1, Q8IU53
# 12003                          A8MTL9, P0C7T4
# 12993                          Q8NFQ8, Q9H496
# 13269                          Q96RT6, Q9HC47
# 13544                          B7ZAP0, Q5R372
# 14007                          C0HLU2, Q96CS4
# 14383                          P39880, Q13948
# 14496                          A6ZKI3, O15255
# 14764                          L0R8F8, Q9NQG6
# 15898                          P0DPQ6, P35638
# 18561                          C0HLS1, Q14160
# 19218                          O95411, Q92614
# 19860  P61567, P61582, P63130, P63131, P63135
# 20333  P61575, P62685, P63122, P63133, Q902F8
# 22123                          B3EWF7, O95278
# 22368                          P0DP91, Q03468
# 25870                          O43687, Q9P0M2
# 26881                          O95925, Q9BQY6
# 27057          P10265, P10266, P61580, P87889
# 31507          O95467, P63092, P84996, Q5JWF2
# 45557                          O96007, O96033
# 46033                          E9PAV3, Q13765
# 46455                          P58400, Q9ULB1
# 46456                          P58401, Q9P2S2
# 46458                          Q9HDB5, Q9Y4C0
# 48003                          C0HM02, P24723
# 48053                          F7VJQ1, P04156
# 48548                          P0DW28, P98175
